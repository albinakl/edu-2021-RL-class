# %% [markdown]
# <h1 style="color:#333333; text-align:center; line-height: 0;">Reinforcement Learning | Assignment 3</h1>
#
# <br/><br/>
#
# This notebook covers the Deep **Critic** approach.
#
# Complete the code snippets given in the Section 3: there is a places
# to insert your code and string fields for your first and last name. The latter are needed to automatically save the results of the algorithms deployment in .json file. After you did that, please upload the notebook (.ipynb) and .json via https://forms.gle/wzqF43ma7yaDuzUc8.
#
# * Problem 3.1 - NN Critic (30 points)

# %% [markdown]
# ***
#
# <h2 style="color:#A7BD3F;">Section 1: Theory recap</h2>
#
# ### Problem
#
# Let us reformulate the Pendulum problem from the previous assignment in terms of Actor-Critic.
#
# The learning (or, more formally, gradient ascent) here is organized as in the following pseudocode. Generally, the parameters are updated after collecting experience from multiple trajectories of a certain length.
#
# The expected reward will be evaluated by a Neural Network (NN), taking concatenated observation and action vectors as input.
#
# ### Neural Net training
#
# The NN is learned in accordance with the assumption that for the perfectly trained model the following equation holds: Q(observation_curr, action_curr) = reward_curr + gamma * Q(observation_old, action_old). So, with introducing Temporal Difference
#
# $TD = reward + \gamma Q_{old}(x_{old}) - Q_{new}(x_{new})$
#
# the loss function for the net could be formulated as
#
# $loss = \frac{1}{2}TD^2$
#
# Accordingly, the HJB equation reads like:
#
# $Q(obs\_new, act\_new) = reward + \gamma * Q(obs\_old, act\_old)$
#
# With the necessary modifications to the algorithm of the previous assignment, the pseudocode is
#
# <img src="nn_critic.png" alt="REINFORCE" width=75% height=75% />

# %% [markdown]
# ***
#
# <h2 style="color:#A7BD3F;">Section 2: NN recap</h2>
#
# First, let us recall the process of NN training.
#
# This network (which is a single Linear layer) should learn how to multiply its input by 2. The train loop, that starts on 33 line, consists of the following:
# * data (input and output) generation
# * zeroing gradients of the model(ltdr for the learning to work correctly)
# * running the net
# * applying criterion to judge how far the correct answer is from the model output
# * calculating gradients of the loss by model parameters
# * performing the weights modification step
#
# If you are not very much familiar with neural networks, examine the code below and familiarize yourself with the methods that are used there. Feel free to play around with the code, uncomment some strings, print random things in order to find out what they are.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim

class Net(nn.Module):
    def __init__(self):
        super().__init__()
                
        self.fc1 = nn.Linear(1, 1)

    def forward(self, x):
        x = self.fc1(x)
        
        return x

net = Net()

lr = 0.01
criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9)

#let us print the parameters of the model
for param in net.parameters():
    print(param)

print("")

episodes_num = 200

for i in range(episodes_num):
    x = torch.tensor([np.random.random_sample()])
    y = x * 2

    optimizer.zero_grad()

    outputs = net(x)
    loss = criterion(outputs, y)

    loss.backward()
    optimizer.step()
    
    loss_val = loss.item()
    
    if (i % 30 == 0):
        print(loss_val)

# for param in net.parameters():
#     print(param.grad * lr)
#     print(param)
#     print("")

print('Finished Training')
print("")
print("test")

for param in net.parameters():
    print(param)

for i in range(5):
    x = torch.tensor([np.random.random_sample()])
    
    outputs = net(x)
    
    print(x, outputs)
# Out:
# Parameter containing:
# tensor([[-0.0838]], requires_grad=True)
# Parameter containing:
# tensor([0.6586], requires_grad=True)
#
# 0.11534121632575989
# 0.049824558198451996
# 0.3921926021575928
# 0.0640149787068367
# 0.014210513792932034
# 0.007354531902819872
# 0.0035941866226494312
# Finished Training
#
# test
# Parameter containing:
# tensor([[1.9060]], requires_grad=True)
# Parameter containing:
# tensor([0.0458], requires_grad=True)
# tensor([0.0920]) tensor([0.2212], grad_fn=<AddBackward0>)
# tensor([0.7881]) tensor([1.5480], grad_fn=<AddBackward0>)
# tensor([0.6091]) tensor([1.2068], grad_fn=<AddBackward0>)
# tensor([0.4776]) tensor([0.9561], grad_fn=<AddBackward0>)
# tensor([0.7087]) tensor([1.3966], grad_fn=<AddBackward0>)

# %% [markdown]
# ***
#
# <h2 style="color:#A7BD3F;">Section 3: Problems</h2>
#
# ### <font color="blue">Problem 3.1 - NN Critic </font>
#
# Complete the code snippet below: add NN critic into the gradient ascent according to the pseudocode above.
#
# * Note the way in which the Pendulum environment is created. It is necessary to manually set the state of the pendulum during the ascent.
# * Class Q_net is added, feel free to modify it if you need.
#
# The output is (as always) a .json file, but in this particular assignment please feel free to modify the length of the training, the length of the episode, to add your custom methods. Generally, the comments ### YOUR SOLUTION BELOW mark those places where the biggest effort is required, but be prepared to modify the code not only there.
#
# * You could modify Q_net: widen the hidden layer, add more hidden layers, etc., whatever needed to make it work
# * Implement custom TD-based loss function
# *

# %%
import gym
import numpy as np
import collections
import sys
from tqdm import tqdm
from IPython.display import clear_output
import time
import matplotlib.pyplot as plt
import math

from gym.envs.classic_control import PendulumEnv

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

def parametrized_swing_up_policy(obs, vartheta, s):
    #normal random variable
    nrv = np.random.normal(0, s, 1)[0]
    
    if (obs[0] > 0.8):
        torque = vartheta[0] * (obs[2] + obs [1]) + nrv
        
        return [torque], nrv
    
    else:
        return [vartheta[1] * obs[2] + nrv], nrv

#x - state
#u - action
#s - sigma of the normal distribution
#nrv - the specific value of the random variable
def param_policy_grad(x, u, s, nrv):
    if (x[0] > 0.8):
        by_0 = nrv * (x[2] + x[1]) / s**2
        
        return np.array([by_0, 0])

    else:
        by_1 = nrv * x[2] / s**2
        
        return np.array([0, by_1])

### YOUR SOLUTION BELOW
class Q_net(nn.Module):
    def __init__(self, inp_dim):
        super().__init__()
        
        self.inp_dim = inp_dim
        
        self.fc1 = nn.Linear(self.inp_dim, self.inp_dim)
        self.fc2 = nn.Linear(self.inp_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        
        return x
### YOUR SOLUTION ABOVE

ep_len = 340

#env = gym.make('Pendulum-v0')
env = PendulumEnv()

env._max_episode_steps = ep_len

def NN_critic(env, update_params, visualize = False):
    observation = env.reset()
    
    ### YOUR SOLUTION BELOW
    vartheta = np.array([-10.0, 0.08])

    PG_updates_num = 1
    episodes_num   = 3
    episode_length = 20
    
    policy = parametrized_swing_up_policy
    
    alpha = 0.001
    sigma = 0.3
    gamma = 0.9
    ### YOUR SOLUTION ABOVE

    reward_history = []
        
    observation_dim, action_dim = 3, 1
    
    q_net      = Q_net(observation_dim + action_dim)
    q_net_copy = Q_net(observation_dim + action_dim)
    
    def run_q_net(q_net, observation, action, w):
        q_net.load_state_dict(w)
                
        net_input = torch.tensor([observation[0], observation[1],
                                  observation[2], action[0]]).float()
        
        return q_net(net_input)
    
    #let us define custom loss function
    def TD_loss(q_net, q_net_copy, reward, observation, action,
                w_prev, obcervation_curr, action_curr, w):
        ### YOUR SOLUTION BELOW
        
        return loss
        ### YOUR SOLUTION ABOVE
    
    optimizer = optim.SGD(q_net.parameters(), lr=alpha, momentum=0.9)
    
    start_state = env.state
    print(start_state)
    
    w      = q_net.state_dict()
    w_prev = q_net.state_dict()
    
    for PG_step in range(PG_updates_num):
        Grad = np.array([0.0, 0.0])
        Sum_Grad_over_episodes = np.array([0.0, 0.0])

        sum_acc_rewards_over_episodes = 0
        sum_param_policy_PDF_grad_acc_over_episodes = 0
        
        skip_loss_calculation = True
        
        for ep in range(episodes_num):
            print("ep", ep)
            
            acc_reward = 0
            policy_PDF_grad_acc = np.array([0.0, 0.0])
            
            ####env.reset_state_into_init_state
            env.state = start_state
            print(env.state)
            
            #run_q_net(q_net_copy, observation_curr, action_curr, w)

            for time_step in range(episode_length):
                if (visualize == True):
                    env.render()
                
                #print(env.state)
                
                action, nrv = policy(observation, vartheta, sigma)
                observation, reward, done, info = env.step(action)
                reward_history.append(reward)

                #HJB: Q(observation_curr, action_curr) = reward_curr + gamma * Q(observation, action)
                
                if (not skip_loss_calculation):
                    ### YOUR SOLUTION ABOVE

                    ### YOUR SOLUTION ABOVE
                
                else:
                    skip_loss_calculation = False
                
                time.sleep(0.01)
                
                observation_curr, reward_curr, action_curr = observation, reward, action
                
                #It's a standard backprop on loss = 1/2 TD^2!
                #w -= - alpha_w * TD * grad_Q_NN(observation_curr, action_curr, w)
                
                #w_prev = w
                w_prev = q_net_copy.state_dict()
                q_net_copy.load_state_dict(q_net.state_dict())

                ppg = param_policy_grad(observation, action, sigma, nrv)
                                
                Q = run_q_net(q_net, observation, action, w).detach().numpy()
                
                Grad = ppg * Q

                #print(q_net.state_dict())
                #print("ppg, Q", ppg, Q)
                
                Sum_Grad_over_episodes += Grad

                sum_acc_rewards_over_episodes += acc_reward
                sum_param_policy_PDF_grad_acc_over_episodes += policy_PDF_grad_acc

        Grad = 1 / episodes_num * Sum_Grad_over_episodes
        
        #print("grad", Sum_Grad_over_episodes)
        
        if (update_params):
            vartheta += alpha * Grad
    
    print(vartheta)
    
    return reward_history

nn_critic_reward_history = REINFORCE(env, update_params = True, visualize = True)

env.close()
# Out:
# [0.41171236 0.88141551]
# ep 0
# [0.41171236 0.88141551]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1754, -0.3301,  0.3262, -0.4465],
#         [ 0.2348,  0.2748, -0.1653, -0.4886],
#         [-0.4261,  0.2213,  0.4468,  0.3506]])), ('fc1.bias', tensor([-0.3771, -0.2103, -0.4741, -0.2946])), ('fc2.weight', tensor([[-0.0742,  0.1239, -0.3416,  0.3812]])), ('fc2.bias', tensor([0.3154]))])
# ppg, Q [-0.65112494  0.        ] [-1.0269294]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1755, -0.3301,  0.3262, -0.4468],
#         [ 0.2347,  0.2748, -0.1654, -0.4876],
#         [-0.4261,  0.2213,  0.4468,  0.3506]])), ('fc1.bias', tensor([-0.3771, -0.2102, -0.4741, -0.2946])), ('fc2.weight', tensor([[-0.0742,  0.1252, -0.3402,  0.3811]])), ('fc2.bias', tensor([0.3156]))])
# ppg, Q [-2.62037274  0.        ] [-1.0656366]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1755, -0.3300,  0.3263, -0.4479],
#         [ 0.2346,  0.2747, -0.1656, -0.4847],
#         [-0.4261,  0.2213,  0.4468,  0.3505]])), ('fc1.bias', tensor([-0.3771, -0.2102, -0.4743, -0.2946])), ('fc2.weight', tensor([[-0.0742,  0.1292, -0.3361,  0.3811]])), ('fc2.bias', tensor([0.3163]))])
# ppg, Q [3.79556323 0.        ] [-1.0309392]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1757, -0.3299,  0.3264, -0.4504],
#         [ 0.2341,  0.2744, -0.1661, -0.4780],
#         [-0.4261,  0.2213,  0.4468,  0.3505]])), ('fc1.bias', tensor([-0.3771, -0.2100, -0.4748, -0.2946])), ('fc2.weight', tensor([[-0.0742,  0.1381, -0.3269,  0.3810]])), ('fc2.bias', tensor([0.3177]))])
# ppg, Q [-1.46495894  0.        ] [-1.0029991]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1760, -0.3298,  0.3268, -0.4551],
#         [ 0.2334,  0.2740, -0.1669, -0.4658],
#         [-0.4261,  0.2213,  0.4469,  0.3503]])), ('fc1.bias', tensor([-0.3771, -0.2097, -0.4757, -0.2946])), ('fc2.weight', tensor([[-0.0742,  0.1546, -0.3101,  0.3809]])), ('fc2.bias', tensor([0.3202]))])
# ppg, Q [0.         3.66147751] [-0.7712687]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0497],
#         [ 0.1763, -0.3296,  0.3271, -0.4617],
#         [ 0.2324,  0.2733, -0.1682, -0.4486],
#         [-0.4262,  0.2212,  0.4465,  0.3501]])), ('fc1.bias', tensor([-0.3771, -0.2093, -0.4769, -0.2948])), ('fc2.weight', tensor([[-0.0743,  0.1777, -0.2865,  0.3805]])), ('fc2.bias', tensor([0.3231]))])
# ppg, Q [0.        4.4463801] [0.5017544]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0498],
#         [ 0.1767, -0.3293,  0.3277, -0.4701],
#         [ 0.2312,  0.2725, -0.1697, -0.4270],
#         [-0.4264,  0.2211,  0.4464,  0.3496]])), ('fc1.bias', tensor([-0.3771, -0.2088, -0.4783, -0.2949])), ('fc2.weight', tensor([[-0.0743,  0.2072, -0.2566,  0.3802]])), ('fc2.bias', tensor([0.3272]))])
# ppg, Q [ 0.         -6.43721217] [0.6191623]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0499],
#         [ 0.1774, -0.3287,  0.3291, -0.4801],
#         [ 0.2298,  0.2716, -0.1715, -0.4014],
#         [-0.4262,  0.2215,  0.4476,  0.3492]])), ('fc1.bias', tensor([-0.3771, -0.2079, -0.4801, -0.2946])), ('fc2.weight', tensor([[-0.0744,  0.2428, -0.2212,  0.3810]])), ('fc2.bias', tensor([0.3332]))])
# ppg, Q [0.         1.48092738] [0.81422114]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0499],
#         [ 0.1784, -0.3275,  0.3325, -0.4915],
#         [ 0.2281,  0.2704, -0.1736, -0.3722],
#         [-0.4256,  0.2227,  0.4521,  0.3487]])), ('fc1.bias', tensor([-0.3771, -0.2063, -0.4821, -0.2933])), ('fc2.weight', tensor([[-0.0745,  0.2849, -0.1808,  0.3847]])), ('fc2.bias', tensor([0.3426]))])
# ppg, Q [ 0.         -7.87111064] [1.0411425]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3150, -0.0277,  0.0500],
#         [ 0.1798, -0.3252,  0.3404, -0.5039],
#         [ 0.2263,  0.2692, -0.1760, -0.3397],
#         [-0.4245,  0.2255,  0.4629,  0.3485]])), ('fc1.bias', tensor([-0.3772, -0.2035, -0.4843, -0.2902])), ('fc2.weight', tensor([[-0.0746,  0.3345, -0.1359,  0.3953]])), ('fc2.bias', tensor([0.3572]))])
# ppg, Q [0.         9.05945231] [1.3637512]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3149, -0.0278,  0.0501],
#         [ 0.1816, -0.3208,  0.3577, -0.5160],
#         [ 0.2243,  0.2678, -0.1787, -0.3043],
#         [-0.4229,  0.2311,  0.4859,  0.3501]])), ('fc1.bias', tensor([-0.3772, -0.1984, -0.4867, -0.2843])), ('fc2.weight', tensor([[-0.0747,  0.3927, -0.0871,  0.4206]])), ('fc2.bias', tensor([0.3796]))])
# ppg, Q [ 0.         41.89790313] [1.8538369]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3149, -0.0279,  0.0501],
#         [ 0.1830, -0.3129,  0.3941, -0.5274],
#         [ 0.2221,  0.2664, -0.1816, -0.2663],
#         [-0.4216,  0.2409,  0.5312,  0.3537]])), ('fc1.bias', tensor([-0.3772, -0.1896, -0.4894, -0.2739])), ('fc2.weight', tensor([[-0.0748,  0.4651, -0.0347,  0.4731]])), ('fc2.bias', tensor([0.4137]))])
# ppg, Q [ 0.         -6.97383054] [2.7365422]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3149, -0.0280,  0.0502],
#         [ 0.1823, -0.2994,  0.4672, -0.5379],
#         [ 0.2198,  0.2648, -0.1847, -0.2259],
#         [-0.4225,  0.2569,  0.6164,  0.3593]])), ('fc1.bias', tensor([-0.3772, -0.1744, -0.4922, -0.2565])), ('fc2.weight', tensor([[-0.0750,  0.5633,  0.0207,  0.5736]])), ('fc2.bias', tensor([0.4647]))])
# ppg, Q [  0.         -32.80045571] [4.3483624]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3148, -0.0283,  0.0503],
#         [ 0.1754, -0.2785,  0.6082, -0.5452],
#         [ 0.2174,  0.2631, -0.1881, -0.1833],
#         [-0.4295,  0.2810,  0.7732,  0.3693]])), ('fc1.bias', tensor([-0.3773, -0.1487, -0.4951, -0.2278])), ('fc2.weight', tensor([[-0.0752,  0.7071,  0.0787,  0.7592]])), ('fc2.bias', tensor([0.5395]))])
# ppg, Q [0.        1.4479948] [7.754983]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3148, -0.0287,  0.0504],
#         [ 0.1552, -0.2498,  0.8713, -0.5460],
#         [ 0.2149,  0.2614, -0.1916, -0.1389],
#         [-0.4506,  0.3134,  1.0597,  0.3870]])), ('fc1.bias', tensor([-0.3774, -0.1056, -0.4982, -0.1805])), ('fc2.weight', tensor([[-0.0755,  0.9373,  0.1387,  1.0924]])), ('fc2.bias', tensor([0.6469]))])
# ppg, Q [  0.         -11.86997553] [15.844579]
# OrderedDict([('fc1.weight', tensor([[-0.2579,  0.3147, -0.0294,  0.0504],
#         [ 0.1096, -0.2176,  1.3518, -0.5356],
#         [ 0.2123,  0.2595, -0.1950, -0.0927],
#         [-0.4997,  0.3495,  1.5883,  0.4179]])), ('fc1.bias', tensor([-0.3775, -0.0331, -0.5014, -0.1004])), ('fc2.weight', tensor([[-0.0759,  1.3396,  0.2003,  1.6850]])), ('fc2.bias', tensor([0.7981]))])
# ppg, Q [  0.        -19.8697803] [36.400677]
# OrderedDict([('fc1.weight', tensor([[-0.2578,  0.3146, -0.0304,  0.0505],
#         [ 0.0232, -0.1957,  2.2031, -0.5009],
#         [ 0.2095,  0.2576, -0.1981, -0.0450],
#         [-0.5968,  0.3718,  2.5551,  0.4787]])), ('fc1.bias', tensor([-0.3776,  0.0885, -0.5047,  0.0375])), ('fc2.weight', tensor([[-0.0766,  2.0679,  0.2628,  2.7246]])), ('fc2.bias', tensor([1.0058]))])
# ppg, Q [0.         0.71317227] [91.72513]
# OrderedDict([('fc1.weight', tensor([[-2.5767e-01,  3.1459e-01, -3.1749e-02,  5.0487e-02],
#         [-1.2472e-01, -2.2263e-01,  3.7365e+00, -4.0134e-01],
#         [ 2.0655e-01,  2.5552e-01, -2.0054e-01,  4.2580e-03],
#         [-7.6979e-01,  3.2951e-01,  4.3754e+00,  6.2282e-01]])), ('fc1.bias', tensor([-0.3779,  0.3009, -0.5079,  0.2891])), ('fc2.weight', tensor([[-0.0775,  3.4558,  0.3257,  4.6077]])), ('fc2.bias', tensor([1.2869]))])
# ppg, Q [ 0.         24.48341355] [252.84154]
# OrderedDict([('fc1.weight', tensor([[-0.2575,  0.3146, -0.0337,  0.0504],
#         [-0.3607, -0.4468,  6.9767, -0.0703],
#         [ 0.2034,  0.2532, -0.2013,  0.0550],
#         [-1.0545,  0.0249,  8.4208,  1.0729]])), ('fc1.bias', tensor([-0.3781,  0.7517, -0.5110,  0.8518])), ('fc2.weight', tensor([[-0.0792,  6.6234,  0.3879,  8.6707]])), ('fc2.bias', tensor([1.6793]))])
# ppg, Q [ 0.         39.52306567] [860.92175]
# OrderedDict([('fc1.weight', tensor([[-0.2573,  0.3147, -0.0371,  0.0503],
#         [-0.5660, -1.8808, 18.3060,  0.9305],
#         [ 0.2003,  0.2500, -0.1967,  0.1073],
#         [-1.2961, -1.8674, 23.0476,  2.4023]])), ('fc1.bias', tensor([-0.3786,  2.4553, -0.5133,  3.0536])), ('fc2.weight', tensor([[-0.0828, 18.4721,  0.4464, 23.2139]])), ('fc2.bias', tensor([2.3287]))])
# ppg, Q [ 0.       -7.982143] [5735.71]
# OrderedDict([('fc1.weight', tensor([[-2.5743e-01,  3.1580e-01, -4.6158e-02,  4.9429e-02],
#         [ 6.0790e+00, -2.1022e+01,  1.3880e+02,  1.5187e+01],
#         [ 1.9863e-01,  2.4209e-01, -1.6262e-01,  1.6419e-01],
#         [ 7.0754e+00, -2.6073e+01,  1.7524e+02,  2.0425e+01]])), ('fc1.bias', tensor([-0.3801, 23.2506, -0.5106, 29.3064])), ('fc2.weight', tensor([[-9.7471e-02,  1.4361e+02,  4.8484e-01,  1.8013e+02]])), ('fc2.bias', tensor([4.1818]))])
# ppg, Q [ 0.         12.56645724] [312798.97]
# OrderedDict([('fc1.weight', tensor([[-2.9398e-01,  3.6653e-01, -3.6187e-01,  5.6643e-02],
#         [ 5.3513e+03, -7.2571e+03,  4.4770e+04, -1.2341e+03],
#         [ 3.7843e-01, -1.3255e-02,  1.3973e+00,  1.8205e-01],
#         [ 6.7115e+03, -9.1024e+03,  5.6157e+04, -1.5463e+03]])), ('fc1.bias', tensor([-4.4331e-01,  9.0217e+03, -2.0088e-01,  1.1316e+04])), ('fc2.weight', tensor([[-7.6024e-01,  4.5892e+04, -3.7835e-01,  5.7876e+04]])), ('fc2.bias', tensor([69.5108]))])
# ppg, Q [  0.         -32.82762387] [2.8451193e+10]
# OrderedDict([('fc1.weight', tensor([[-3.0012e+04,  2.6130e+04, -1.7273e+05,  3.4920e+03],
#         [ 1.8116e+11, -1.5773e+11,  1.0426e+12, -2.1079e+10],
#         [-1.4936e+06,  1.3004e+06, -8.5961e+06,  1.7379e+05],
#         [ 2.2847e+11, -1.9892e+11,  1.3149e+12, -2.6583e+10]])), ('fc1.bias', tensor([-3.9793e+04,  2.4020e+11, -1.9804e+06,  3.0293e+11])), ('fc2.weight', tensor([[-1.2988e+05,  1.1110e+12,  3.2150e+07,  1.3936e+12]])), ('fc2.bias', tensor([5234347.]))])
# ppg, Q [  0.         -23.35651081] [1.4365651e+25]
# OrderedDict([('fc1.weight', tensor([[-2.7467e+24,  1.5818e+24, -1.2289e+25, -6.0908e+23],
#         [ 2.3495e+33, -1.3531e+33,  1.0512e+34,  5.2100e+32],
#         [ 6.7988e+26, -3.9155e+26,  3.0418e+27,  1.5076e+26],
#         [ 2.9470e+33, -1.6972e+33,  1.3185e+34,  6.5350e+32]])), ('fc1.bias', tensor([-3.1696e+24,  2.7113e+33,  7.8457e+26,  3.4008e+33])), ('fc2.weight', tensor([[-1.8249e+25,  1.1016e+34, -9.0823e+26,  1.3893e+34]])), ('fc2.bias', tensor([2.4403e+21]))])
# ppg, Q [-5.82100098  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [13.65588404  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-5.35709596  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.80138043  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [7.72620638 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-2.78844385  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-5.47567513  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [6.32092068 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-4.77631359  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.17495324 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.25381567  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [2.94561421 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-1.09077264  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.16509219  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.38639498 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.34497107  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.15739963  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.39051677  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.10308736  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.21619385 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [1.45436131 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.51903086 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.1872476  0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01551955 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.6208466 0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.64139778 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.16617452 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.14940478  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.2170695  0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.14606753  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.30154701 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.16527797 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00304346  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.02908115  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.36461443 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.32927306 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.46938618 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01420244 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07073578 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.31800434 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.05031803  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.15772476  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02362527 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.36968021 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07172464 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.10036803 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01151059 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.32806519 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01323556  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.23393731 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.33334651 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.04777382 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00644494  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.05042426  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.65886474 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.08468463 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.28592489 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07927972 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.04196356  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.50562918 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.47687414 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.12985682  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.62138407 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01475781 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.03188273  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.21411321 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.00279542 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.82709057 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00132074  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07229525 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00373191  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.24463382 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00021064  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00449213  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01086588  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.05329087 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.1586956 0.       ] [nan]
# ep 1
# [0.41171236 0.88141551]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.21315718 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.03398375 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.19430726 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.05121591 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.03211893  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00491067  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01898537  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.59168752 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00429007  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.41467095 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07829131 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02890382 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01119265 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01282096  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.67482475 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01678991  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.17528625 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.21086257 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.06743262 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.00420505 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.62215227 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.04204977 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00540181  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07036298 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02624826 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.06919651 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.90310861 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.17128922 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.11946325 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.79386731 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.05406305 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.12132096 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.06512715 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.02212078  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.40580966 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02746666 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01340637 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00137354  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.06256483 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.62338247 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.02593265  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.00660298 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.44152053 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00622863  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
# ...
# ppg, Q [0.58515154 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01444234 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01702506 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01407948 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.12649695 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.00479989 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01572194 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.03425099 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.0641731 0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.16698774 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.60720095 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.03268093  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.66563718 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.47626009 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.39328997 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.0441319  0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02434296 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.02180128 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.21313709 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00216041  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.3993739 0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.34067463 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.32213951 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.03663987  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.52237523 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.01831282  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00102902  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [1.07662685 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.04832611  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.20725109 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.36061442 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.23886999 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.02415842  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.04733231 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.04358974 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.11938773 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.0062252 0.       ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.10204216 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.04579614 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.10219149 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.49503627 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.04333014  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.12019266 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.07440001 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.03030424 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.12890934 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.00668111 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.06971593 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.16798657 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [-0.00118443  0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01673778 0.        ] [nan]
# OrderedDict([('fc1.weight', tensor([[nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan],
#         [nan, nan, nan, nan]])), ('fc1.bias', tensor([nan, nan, nan, nan])), ('fc2.weight', tensor([[nan, nan, nan, nan]])), ('fc2.bias', tensor([nan]))])
# ppg, Q [0.01042734 0.        ] [nan]
# grad [nan nan]
# [nan nan]

# %% [markdown]
# ### <font color="orange">Auto-grading</font>
# Run this cell to track your answers and to save your answer for problem 3.1. Make sure you defined the necessary variable above to avoid a `NameError` below.

# %%
### GRADING DO NOT MODIFY
from grading_utilities import AnswerTracker
asgn1_answers = AnswerTracker()
asgn1_answers.record('problem_3-1', {'reward_history': nn_critic_reward_history})

# %% [markdown]
# ### <font color="orange">Auto-grading: Submit your answers</font>
# Enter your first and last name in the cell below and then run it to save your answers for this assumption to a JSON file. The file is saved next to this notebook. After the file is created, upload the JSON file and the notebook via the form provided in the beginning of the assumption.

# %%
assignment_name = "asgn_3"
first_name = ""
last_name = ""

asgn2_answers.save_to_json(assignment_name, first_name, last_name)

# %% [markdown]
# ## Questions?
#
# Reach out to Ilya Osokin (@elijahmipt) on Telegram.
#
# ## Sources
#
# ***
#
# <sup>[1]</sup> Ng, A. Stanford University, CS229 Notes: Reinforcement Learning and Control.
#
# <sup>[2]</sup> Barnabás Póczos, Carnegie Mellon, Introduction To Machine Learning: Reinforcement Learning (Course).
#
# <sup>[3]</sup> **Sutton, R. S., Barto, A. G. (2018 ). Reinforcement Learning: An Introduction. The MIT Press.**
#
# <sup>[4]</sup> OpenAI: Spinning Up. Retrieved from https://spinningup.openai.com/en/latest/spinningup/rl_intro.html
